# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
#read the csv file
df = pd.read_csv('US_Accidents_Dec21_updated.csv')

# %%
#check the dimension of csv
df.shape
# Out:
# (2845342, 47)

# %%
#check the head of csv
df.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1  A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20  39.865420
# 2  A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39  39.102660
# 3  A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45  41.062130
# 4  A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
#
#    Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0 -83.092860  40.112060 -83.031870         3.230
# 1 -84.062800  39.865010 -84.048730         0.747
# 2 -84.524680  39.102090 -84.523960         0.055
# 3 -81.537840  41.062170 -81.535470         0.123
# 4 -84.492792  39.170476 -84.501798         0.500
#
#                                          Description  ...  Roundabout Station  \
# 0  Between Sawmill Rd/Exit 20 and OH-315/Olentang...  ...       False   False
# 1                 At OH-4/OH-235/Exit 41 - Accident.  ...       False   False
# ...

# %%
#check the all the columns variable
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
#check the type of the dataset
df.dtypes
# Out:
# ID                        object
# Severity                   int64
# Start_Time                object
# End_Time                  object
# Start_Lat                float64
# Start_Lng                float64
# End_Lat                  float64
# End_Lng                  float64
# Distance(mi)             float64
# Description               object
# Number                   float64
# Street                    object
# Side                      object
# City                      object
# County                    object
# State                     object
# Zipcode                   object
# Country                   object
# Timezone                  object
# Airport_Code              object
# Weather_Timestamp         object
# Temperature(F)           float64
# Wind_Chill(F)            float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# Wind_Direction            object
# Wind_Speed(mph)          float64
# ...

# %%
#check the min max ave of the numeric variable
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06
# mean   2.137572e+00  3.624520e+01 -9.711463e+01  3.624532e+01 -9.711439e+01
# std    4.787216e-01  5.363797e+00  1.831782e+01  5.363873e+00  1.831763e+01
# min    1.000000e+00  2.456603e+01 -1.245481e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.344517e+01 -1.180331e+02  3.344628e+01 -1.180333e+02
# 50%    2.000000e+00  3.609861e+01 -9.241808e+01  3.609799e+01 -9.241772e+01
# 75%    2.000000e+00  4.016024e+01 -8.037243e+01  4.016105e+01 -8.037338e+01
# max    4.000000e+00  4.900058e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)        Number  Temperature(F)  Wind_Chill(F)  \
# count  2.845342e+06  1.101431e+06    2.776068e+06   2.375699e+06
# mean   7.026779e-01  8.089408e+03    6.179356e+01   5.965823e+01
# std    1.560361e+00  1.836009e+04    1.862263e+01   2.116097e+01
# ...

# %%
#remove unnecessary columns
df = df[['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
    'End_Lat', 'End_Lng', 'Distance(mi)', 
    #'Description', 'Number', 'Street','Side', 
    'City', 'County', 'State', 'Zipcode', 
    #'Country', 'Timezone','Airport_Code', 
    'Weather_Timestamp', 'Temperature(F)', 
    #'Wind_Chill(F)',
       'Humidity(%)', 
    #'Pressure(in)', 
    'Visibility(mi)', 
    #'Wind_Direction',
       'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
       'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
       'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
       'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
       'Astronomical_Twilight']].copy()

# %%
#convert time into datetime format
df['End_Time'] = pd.to_datetime(df['End_Time'])
df['Start_Time'] = pd.to_datetime(df['Start_Time'])

# %%
#rename columns
#df.rename(columns={'ID':'ID2','City':'City2'})
# Out:
#                ID2  Severity          Start_Time            End_Time  \
# 0              A-1         3 2016-02-08 00:37:08 2016-02-08 06:37:08
# 1              A-2         2 2016-02-08 05:56:20 2016-02-08 11:56:20
# 2              A-3         2 2016-02-08 06:15:39 2016-02-08 12:15:39
# 3              A-4         2 2016-02-08 06:51:45 2016-02-08 12:51:45
# 4              A-5         3 2016-02-08 07:53:43 2016-02-08 13:53:43
# ...            ...       ...                 ...                 ...
# 2845337  A-2845338         2 2019-08-23 18:03:25 2019-08-23 18:32:01
# 2845338  A-2845339         2 2019-08-23 19:11:30 2019-08-23 19:38:23
# 2845339  A-2845340         2 2019-08-23 19:00:21 2019-08-23 19:28:49
# 2845340  A-2845341         2 2019-08-23 19:00:21 2019-08-23 19:29:42
# 2845341  A-2845342         2 2019-08-23 18:52:06 2019-08-23 19:21:31
#
#          Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 0        40.108910  -83.092860  40.112060  -83.031870         3.230
# ...

# %%
#check any missing values in the columns
df.isna().sum()
# Out:
# ID                            0
# Severity                      0
# Start_Time                    0
# End_Time                      0
# Start_Lat                     0
# Start_Lng                     0
# End_Lat                       0
# End_Lng                       0
# Distance(mi)                  0
# City                        137
# County                        0
# State                         0
# Zipcode                    1319
# Weather_Timestamp         50736
# Temperature(F)            69274
# Humidity(%)               73092
# Visibility(mi)            70546
# Wind_Speed(mph)          157944
# Precipitation(in)        549458
# Weather_Condition         70636
# Amenity                       0
# Bump                          0
# Crossing                      0
# Give_Way                      0
# Junction                      0
# No_Exit                       0
# Railway                       0
# Roundabout                    0
# Station                       0
# ...

# %%
#remove duplicate records
df = df.loc[~df.duplicated(subset=['Start_Time','End_Time','Start_Lat', 'Start_Lng','End_Lat', 'End_Lng'])].reset_index(drop=True)

# %%
df.shape
# Out:
# (2807623, 37)

# %%
#plot the highest number of accident by city
ax = df['City'].value_counts().head(10).plot(kind='barh', title='Highest Accident City')
ax.set_xlabel('Number')
ax.set_ylabel('City')
# Out:
# Text(0, 0.5, 'City')

# %%
#plot histrogram sample
df['Severity'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#plot scatter plot sample
df.plot(kind='scatter', x='Visibility(mi)', y='Precipitation(in)')
# Out:
# <AxesSubplot:xlabel='Visibility(mi)', ylabel='Precipitation(in)'>

# %%
#plot different scatter plot and determine relationship
sns.pairplot(df, vars=['Severity', 'Temperature(F)', 'Humidity(%)',  'Visibility(mi)', 'Wind_Speed(mph)'])
plt.show()

# %%
#remove empty value
df = df.dropna().reset_index(drop=True)

# %%
#remove impossible temperature
df = df[df['Temperature(F)'] < 122].reset_index(drop=True)

# %%
#remove impossible windspeed
df = df[(df['Wind_Speed(mph)'] < 200) & (df['Wind_Speed(mph)'] >= 0)].reset_index(drop=True)

# %%
#remove weather timestamp columns
df= df.drop(columns='Weather_Timestamp')

# %%
#save into csv
df.to_csv('US_Accidents_cleaned.csv', encoding='utf-8')
